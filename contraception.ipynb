# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import UnexpectedAlertPresentException
from selenium.common.exceptions import NoAlertPresentException
import requests
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
from selenium.webdriver.support.select import Select

PATH = "C:\Program Files (x86)\chromedriver.exe"
driver = webdriver.Chrome(PATH)

driver.get("https://passmedicine.com/index.php")
username_field = driver.find_element_by_name("username")
password_field = driver.find_element_by_name("password")
login_button = driver.find_element_by_name("login")

username = "drumkabir@gmail.com"
password = "brain00000"

username_field.send_keys(username)
password_field.send_keys(password)
login_button.click()


cl = driver.find_element_by_class_name("close")
cl.click()

review = driver.find_element_by_xpath("/html/body/nav/div/ul/li[1]/a")
review.click()

driver.implicitly_wait(60)
ques = driver.find_element_by_xpath("/html/body/nav/div/ul/li[1]/div/a[1]")
ques.click()



# obj = Select(driver.find_element_by_class_name("Q-category-selector"))
# obj.deselect_(self, 'Ophthalmology')



driver.implicitly_wait(60)
# ophth = driver.find_element_by_css_selector("#list-item-category-6 > div:nth-child(1) > div:nth-child(1) > label:nth-child(2)")
# ophth.click()
driver.refresh()

subd = WebDriverWait(driver, 60).until(EC.element_to_be_clickable((By.XPATH,"/html/body/div/div/div[1]/ul/li[12]/div[1]/div/a/i")))
subd.click()

rheu = driver.find_element_by_xpath("/html/body/div/div/div[1]/ul/li[12]/div[2]/div/ul/li[1]/div/div/label")
rheu.click()



# show = WebDriverWait(driver, 300).until(EC.element_to_be_clickable((By.XPATH,"//*[@id='showallquestions']")))
# show.click()



driver.implicitly_wait(60)
# rev = driver.find_element_by_link_text('Review')
rev = WebDriverWait(driver, 120).until(EC.element_to_be_clickable((By.XPATH,"/html/body/div/div/div[2]/table/tbody/tr[1]/td[4]/a")))
rev.click()

datalist = ""
soupf2 = ""

for x in range(1,60):
    driver.implicitly_wait(300)
    WebDriverWait(driver, 60).until(EC.text_to_be_present_in_element((By.ID,"questionXofY"),"Question"+" "+str(x)))
    WebDriverWait(driver, 240).until(EC.text_to_be_present_in_element((By.XPATH,"/html/body/footer/p[1]/a"),"Back to top"))
    soup = BeautifulSoup(driver.page_source, 'lxml')
    html = soup.prettify("utf-8")
#     ques = "<h3 style='color:blue'>Question: "+ str(x) + "</h3>" +str(soup.find("div", {"class": "col-lg-7"}))

    driver.implicitly_wait(10)
    
    soupf = soup.find("div", {"id": "div_question"})
    
    ques = ""
    exp = ""
#     WebDriverWait(driver, 10).until(EC.text_to_be_present_in_element((By.XPATH,"//*[@id='questionXofY']/span"),str(x)))
#     ques = "<h3 style='color:blue'>Question: "+ str(x) + "</h3>" +str(soup.find("div", {"id": "div_question"}))
#     exp = "<h4 style='text-decoration:underline'>Explanation: "+ "</h4>" +str(soup.find("div", {"id": "div_notes"}))
    
    
    if soupf2 != soupf and x==16 or x==18 or x==28:
        exp = ""
        ques = "<h3 style='color:blue'>Question: "+ str(x) + "</h3>" +str(soup.find("div", {"id": "div_question"}))
        WebDriverWait(driver, 240).until(EC.text_to_be_present_in_element((By.XPATH,"/html/body/footer/p[1]/a"),"Back to top"))
        exp = "<h4 style='text-decoration:underline'>Explanation: "+ "</h4>" +str(soup.find("div", {"id": "div_notes"}))
    else:
        if x==59:
            break
        nex = driver.find_element_by_xpath("/html/body/div[3]/div/div[1]/div[1]/div/div[5]/button/i")
        nex.click()
        continue
        soup = BeautifulSoup(driver.page_source, 'lxml')
        html = soup.prettify("utf-8")
        
        ques = "<h3 style='color:blue'>Question: "+ str(x) + "</h3>" +str(soup.find("div", {"id": "div_question"}))
        exp = "<h4 style='text-decoration:underline'>Explanation: "+ "</h4>" +str(soup.find("div", {"id": "div_notes"}))
    
# #         linki = WebDriverWait(driver, 120).until(EC.element_to_be_clickable((By.XPATH,"//*[@id='div_dashboard']/table/tbody/tr[x+1]/td[1]/a")))
# #         linki.click()
        
#         ques = "<h3 style='color:blue'>Question: "+ str(x) + "</h3>" +str(soup.find("div", {"id": "div_question"}))
#         exp = "<h4 style='text-decoration:underline'>Explanation: "+ "</h4>" +str(soup.find("div", {"id": "div_notes"}))

    soupf2 = soup.find("div", {"id": "div_question"})
    
    datalist = datalist + ques + exp + "------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------"+ "\n\n"
    driver.implicitly_wait(60)
    
    if x==59:
        break
#     nex = driver.find_element_by_xpath("//*[@id='div_dashboard']/table/tbody/tr[x+1]/td[1]/b")
#     nex.click()
#     p=p+1


#     nex = driver.find_element_by_link_text(str(x+1))
#     nex.click()
      
      
    
    nex = driver.find_element_by_xpath("/html/body/div[3]/div/div[1]/div[1]/div/div[5]/button/i")
    nex.click()
    driver.implicitly_wait(300)
    
    
  
    
    
    
with open("contraception extra.html", "w", encoding="utf-8") as file:
    file.write("""<!DOCTYPE html>
<html>
<head>
    <link rel="stylesheet" href="autobot.css">
</head>
<body><div class="container"><h1><center>Women's Health: Contraception</center></h1>""" + datalist + "</div></body></html>")
